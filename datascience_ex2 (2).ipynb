# %%
import pandas as pd

# %%
df=pd.read_excel('APznzaavH88Pq-1BbqExOKBPP3NYqIJG5pahgY6MTuWzaggijN5j95YRjEG5aWEpa_C4yxxLLZCicDiBAg_eONdm9_v-PbuQIX5VxDMXjEG7R5CBwU6p9HPV9nZMCH0oAyp4wZBZAdJzzArzVlqQrRuJUhDTpKr9J30lqO6WpisvnBl9oxFn6V7vKLMBi7_Ul144v2pC0vkK3BL77G5T1.xlsx')

# %%
null_col=df.columns[df.isnull().any()]

# %%
print(null_col)
# Out:
# Index(['Price', 'Bathrooms', 'Sqft_Living', 'Sqft_Lot'], dtype='object')

# %%
df
# Out:
#        ID      Price  Bedrooms  Bathrooms  Sqft_Living  Sqft_Lot  Floors  \
# 0       1  224835.71         4        3.0      1659.70   5141.78       1
# 1       2  193086.78         1        3.4      1564.66   3207.94       1
# 2       3  232384.43         3        1.3          NaN       NaN       2
# 3       4  276151.49         5        3.8      1177.98   6086.91       1
# 4       5  188292.33         3        3.4          NaN   3610.07       1
# ..    ...        ...       ...        ...          ...       ...     ...
# 995   996  185944.99         3        1.9          NaN   2305.58       1
# 996   997  289884.33         4        2.8       956.69   3879.75       2
# 997   998  232042.14         1        1.2      1051.94   4500.19       1
# 998   999  171441.05         3        1.5      1026.09       NaN       2
# 999  1000        NaN         2        3.1      1802.73   7036.91       2
#
#      Waterfront  View  Condition  Year_Built
# 0             1     1          2        1901
# ...

# %%
if 'Bathrooms' in null_col:
    mean_room=df['Bathrooms'].mean()
    print(f"Median Price:{mean_room}")
    df['Bathrooms']=df['Bathrooms'].fillna(mean_room)
# Out:
# Median Price:2.5031111111111115

# %%
df
# Out:
#        ID      Price  Bedrooms  Bathrooms  Sqft_Living  Sqft_Lot  Floors  \
# 0       1  224835.71         4        3.0      1659.70   5141.78       1
# 1       2  193086.78         1        3.4      1564.66   3207.94       1
# 2       3  232384.43         3        1.3          NaN       NaN       2
# 3       4  276151.49         5        3.8      1177.98   6086.91       1
# 4       5  188292.33         3        3.4          NaN   3610.07       1
# ..    ...        ...       ...        ...          ...       ...     ...
# 995   996  185944.99         3        1.9          NaN   2305.58       1
# 996   997  289884.33         4        2.8       956.69   3879.75       2
# 997   998  232042.14         1        1.2      1051.94   4500.19       1
# 998   999  171441.05         3        1.5      1026.09       NaN       2
# 999  1000        NaN         2        3.1      1802.73   7036.91       2
#
#      Waterfront  View  Condition  Year_Built
# 0             1     1          2        1901
# ...

# %%
if 'Price' in null_col:
    median_price=df['Price'].median()
    print(f"Mean Bath: {median_price}")
    df['Price']=df['Price'].fillna(median_price)
# Out:
# Mean Bath: 202300.21

# %%
df
# Out:
#        ID      Price  Bedrooms  Bathrooms  Sqft_Living  Sqft_Lot  Floors  \
# 0       1  224835.71         4        3.0      1659.70   5141.78       1
# 1       2  193086.78         1        3.4      1564.66   3207.94       1
# 2       3  232384.43         3        1.3          NaN       NaN       2
# 3       4  276151.49         5        3.8      1177.98   6086.91       1
# 4       5  188292.33         3        3.4          NaN   3610.07       1
# ..    ...        ...       ...        ...          ...       ...     ...
# 995   996  185944.99         3        1.9          NaN   2305.58       1
# 996   997  289884.33         4        2.8       956.69   3879.75       2
# 997   998  232042.14         1        1.2      1051.94   4500.19       1
# 998   999  171441.05         3        1.5      1026.09       NaN       2
# 999  1000  202300.21         2        3.1      1802.73   7036.91       2
#
#      Waterfront  View  Condition  Year_Built
# 0             1     1          2        1901
# ...

# %%
df
# Out:
#        ID      Price  Bedrooms  Bathrooms  Sqft_Living  Sqft_Lot  Floors  \
# 0       1  224835.71         4        3.0      1659.70   5141.78       1
# 1       2  193086.78         1        3.4      1564.66   3207.94       1
# 2       3  232384.43         3        1.3          NaN       NaN       2
# 3       4  276151.49         5        3.8      1177.98   6086.91       1
# 4       5  188292.33         3        3.4          NaN   3610.07       1
# ..    ...        ...       ...        ...          ...       ...     ...
# 995   996  185944.99         3        1.9          NaN   2305.58       1
# 996   997  289884.33         4        2.8       956.69   3879.75       2
# 997   998  232042.14         1        1.2      1051.94   4500.19       1
# 998   999  171441.05         3        1.5      1026.09       NaN       2
# 999  1000  202300.21         2        3.1      1802.73   7036.91       2
#
#      Waterfront  View  Condition  Year_Built
# 0             1     1          2        1901
# ...

# %%
q1=df['Price'].quantile(0.25)
q3=df['Price'].quantile(0.75)
iqr=q3-q1

# %%
lower_bound=q1-1.5*iqr
upper_bound=q3+1.5*iqr

# %%
df_clean=df[(df['Price']>=lower_bound)&(df['Price']<=upper_bound)]

# %%
min_sqft=df_clean['Sqft_Living'].min()
max_sqft=df_clean['Sqft_Living'].max()

# %%
# Make sure to copy df_clean if it's a slice of another DataFrame
df_clean = df_clean.copy()

# Now safely modify the DataFrame
df_clean.loc[:, 'Sqft_Living_Normailized'] = (df_clean['Sqft_Living'] - min_sqft) / (max_sqft - min_sqft)

# %%
df
# Out:
#        ID      Price  Bedrooms  Bathrooms  Sqft_Living  Sqft_Lot  Floors  \
# 0       1  224835.71         4        3.0      1659.70   5141.78       1
# 1       2  193086.78         1        3.4      1564.66   3207.94       1
# 2       3  232384.43         3        1.3          NaN       NaN       2
# 3       4  276151.49         5        3.8      1177.98   6086.91       1
# 4       5  188292.33         3        3.4          NaN   3610.07       1
# ..    ...        ...       ...        ...          ...       ...     ...
# 995   996  185944.99         3        1.9          NaN   2305.58       1
# 996   997  289884.33         4        2.8       956.69   3879.75       2
# 997   998  232042.14         1        1.2      1051.94   4500.19       1
# 998   999  171441.05         3        1.5      1026.09       NaN       2
# 999  1000  202300.21         2        3.1      1802.73   7036.91       2
#
#      Waterfront  View  Condition  Year_Built
# 0             1     1          2        1901
# ...

# %%
df_clean['Year_Built'] = df_clean['Year_Built'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df_clean['Year_Built'] = df_clean['Year_Built'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...
